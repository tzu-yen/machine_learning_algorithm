# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Nclass = 500

X1 = np.random.randn(Nclass, 2) + np.array([0,-2])
X2 = np.random.randn(Nclass, 2) + np.array([2,2])
X3 = np.random.randn(Nclass, 2) + np.array([-2,2])
X = np.vstack((X1, X2, X3))

Y = np.array([0]*Nclass + [1]*Nclass + [2]*Nclass)

plt.scatter(X[:,0], X[:,1], c=Y, s=10, alpha=0.5)

# %%
D = 2
M = 3
K = 3

W1 = np.random.randn(D, M)
b1 = np.random.randn(M)
W2 = np.random.randn(M, K)
b2 = np.random.randn(K)

# %%
def forward(X, W1, b1, W2, b2):
    #hidden layer 1
    Z = 1 / (1 + np.exp(-X.dot(W1)-b1))
    #output layer
    A = Z.dot(W2)+b2
    #softmax
    exp_A = np.exp(A)
    Y = exp_A / exp_A.sum(axis=1, keepdims=True)
    return Y

# %%
def classification_rate(Y, P):
    n_correct = 0
    for i in xrange(len(Y)):
        if Y[i] == P[i]:
            n_correct += 1.0
    return n_correct / len(Y)

# %%
P_Y_given_X = forward(X, W1, b1, W2, b2)
P = np.argmax(P_Y_given_X, axis=1)

assert(len(P)==len(Y))
print "Classification rate for randomly chosen weights:", classification_rate(Y, P)
# Out:
# [[ 0.16327819  0.8135313   0.02319051]
#  [ 0.19955975  0.77062527  0.02981498]
#  [ 0.14871236  0.82103334  0.0302543 ]
#  ...,
#  [ 0.49704691  0.48275446  0.02019863]
#  [ 0.2913722   0.67786734  0.03076045]
#  [ 0.46794386  0.51121198  0.02084416]]
# Classification rate for randomly chosen weights: 0.322666666667
