# %%
from knn import KNN
from util import get_xor
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
if __name__ == '__main__':
    X, y = get_xor()
    plt.scatter(X[:,0], X[:,1], s=100, c=y, alpha=0.5)
    plt.show()
    model = KNN(3)
    model.fit(X, y)
    print 'Trainning Accuracy: ', model.score(X,y)
# Out:
# Trainning Accuracy:  0.975
